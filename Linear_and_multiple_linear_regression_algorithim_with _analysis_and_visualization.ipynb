# %%
import pandas as pd

# %%
df = pd.read_csv('employee_data.csv',delimiter = ',')

# %%
df.head()
# Out:
#    Unnamed: 0  id groups  age  healthy_eating  active_lifestyle  salary
# 0           0   0      A   36               5                 5    2297
# 1           1   1      A   55               3                 5    1134
# 2           2   2      A   61               8                 1    4969
# 3           3   3      O   29               3                 6     902
# 4           4   4      O   34               6                 2    3574

# %%
import numpy as np

# %%
Id = np.array(df['id'])
Groups = np.array(df['groups'])
healthy_eating = np.array(df['healthy_eating'])
Age = np.array(df['age'])
Salary = np.array(df['salary'])
df.head()
# Out:
#    Unnamed: 0  id groups  age  healthy_eating  active_lifestyle  salary
# 0           0   0      A   36               5                 5    2297
# 1           1   1      A   55               3                 5    1134
# 2           2   2      A   61               8                 1    4969
# 3           3   3      O   29               3                 6     902
# 4           4   4      O   34               6                 2    3574

# %%
df.tail()
# Out:
#      Unnamed: 0   id groups  age  healthy_eating  active_lifestyle  salary
# 995         995  995      O   33               7                 7    2996
# 996         996  996      O   21               1                 2     667
# 997         997  997      O   49               9                 7    4158
# 998         998  998     AB   56               6                 7    2414
# 999         999  999      B   64               4                 9     788

# %%
df.shape
# Out:
# (1000, 7)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df1 = df.iloc[:,3:7]
df1.head()
# Out:
#    age  healthy_eating  active_lifestyle  salary
# 0   36               5                 5    2297
# 1   55               3                 5    1134
# 2   61               8                 1    4969
# 3   29               3                 6     902
# 4   34               6                 2    3574

# %%
df1['salary'].unique()
# Out:
# array([2297, 1134, 4969,  902, 3574, 2761, 1484, 3809, 2065, 1020, 1950,
#        4387, 1830, 2182, 3460,  662,  779, 3228, 1360, 3110, 1601, 2414,
#        4390, 1252, 2764, 1833,  785,  670,  556, 2646, 2179, 4155, 2878,
#        3806, 4505, 2300, 3691, 1366, 3342, 4041, 1948, 3225, 1716, 2996,
#        2993, 2056, 1598, 4622, 1011, 3113, 2529,  894, 4158, 1128, 2406,
#        1017, 1475, 2411,  667, 3923, 2532, 4508, 5086, 3345, 5318, 2062,
#        3694, 1478, 1824, 2643,  788, 1369, 5435, 4854, 1707, 1126,  896,
#        1710, 4273, 4276,  553, 3457, 1592, 1137, 3577, 2288, 2294, 1249,
#        1481, 1243, 4038, 4972, 1718, 2174, 2881, 5550, 2875, 1942,  665,
#        1246, 5204], dtype=int64)

# %%
df1.drop_duplicates(subset='age',keep='first',inplace=True)

# %%
df1.drop(['healthy_eating'],axis=1).head()
# Out:
#    age  active_lifestyle  salary
# 0   36                 5    2297
# 1   55                 5    1134
# 2   61                 1    4969
# 3   29                 6     902
# 4   34                 2    3574

# %%
final_data = df1.loc[:,("age","salary")]
final_data.head()
# Out:
#    age  salary
# 0   36    2297
# 1   55    1134
# 2   61    4969
# 3   29     902
# 4   34    3574

# %%
df1.drop([1,2,3],axis=0).head()
# Out:
#    age  healthy_eating  active_lifestyle  salary
# 0   36               5                 5    2297
# 4   34               6                 2    3574
# 5   42               5                 3    2761
# 6   53               4                 6    1484
# 7   41               8                 6    3809

# %%
final_data.describe()
# Out:
#              age       salary
# count  47.000000    47.000000
# mean   41.000000  2400.319149
# std    13.711309  1254.326098
# min    18.000000   662.000000
# 25%    29.500000  1366.000000
# 50%    41.000000  2179.000000
# 75%    52.500000  3460.000000
# max    64.000000  4969.000000

# %%
df1.drop_duplicates(subset='salary',keep='first',inplace=False).shape
# Out:
# (32, 4)

# %%
def half(s):
    return s*0.5

# %%
df1[['salary']].apply(half).head()
# Out:
#    salary
# 0  1148.5
# 1   567.0
# 2  2484.5
# 3   451.0
# 4  1787.0

# %%
df['groups'].value_counts()
# Out:
# O     375
# A     375
# AB    125
# B     125
# Name: groups, dtype: int64

# %%
final_data.sort_values(by='age',ascending=False)[0:10]
# Out:
#     age  salary
# 54   64     670
# 25   63    2414
# 26   62    4390
# 2    61    4969
# 70   60    1830
# 22   59    3460
# 32   58     662
# 15   57     662
# 56   56    2297
# 1    55    1134

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='age',y='salary',data=final_data)
plt.show()

# %%
sns.distplot(df['salary'],hist=False)
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(25,8))
sns.barplot(x='age',y='salary',data=final_data)
plt.show()

# %%
sns.jointplot(x='age',y='salary',data=final_data,color="olive")
plt.show()

# %%
x = list(df['salary'])
x[0:5]
# Out:
# [2297, 1134, 4969, 902, 3574]

# %%
y = list(df['groups'])
y[0:5]
# Out:
# ['A', 'A', 'A', 'O', 'O']

# %%
plt.hist(x,bins=50)
plt.show()

# %%
sns.distplot(df['age'],bins=15)
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df,hue='groups')
plt.show()

# %%
x1 = final_data[['age']]

# %%
y1 = final_data[['salary']]

# %%
# wnt to predict salary accourding to the age.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.3)

# %%
x_train.head()
# Out:
#      age
# 56    56
# 66    27
# 47    44
# 52    28
# 105   48

# %%
x_train.shape
# Out:
# (32, 1)

# %%
y_train.head()
# Out:
#      salary
# 56     2297
# 66     1366
# 47     1484
# 52     4155
# 105    4622

# %%
y_train.shape
# Out:
# (32, 1)

# %%
x_test.shape
# Out:
# (15, 1)

# %%
x_test.head()
# Out:
#     age
# 84   39
# 37   22
# 16   33
# 2    61
# 14   51

# %%
y_test.shape
# Out:
# (15, 1)

# %%
y_test.head()
# Out:
#     salary
# 84    1366
# 37    1134
# 16    1134
# 2     4969
# 14    3460

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_test.head()
# Out:
#     salary
# 84    1366
# 37    1134
# 16    1134
# 2     4969
# 14    3460

# %%
y_pred[0:5]
# Out:
# array([[2669.47343472],
#        [2687.48127026],
#        [2675.82914138],
#        [2646.16917696],
#        [2656.7620214 ]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2092179.0670673284

# %%
# multiple Linear Regression (model - 2 )

# %%
y2 = df1[['salary']]

# %%
x2 = df1[['age','healthy_eating','active_lifestyle']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y2,test_size=0.3)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr2.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[1507.39098939],
#        [3466.40386751],
#        [ 919.24294565],
#        [2314.61081348],
#        [ 915.65713587]])

# %%
y_test.head()
# Out:
#      salary
# 6      1484
# 14     3460
# 180     902
# 56     2297
# 3       902

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 173380.92902506294
